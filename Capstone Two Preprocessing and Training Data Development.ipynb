# %%
import pandas as pd

Student_Mental_Health = pd.read_csv(r'C:\Users\ashna\OneDrive\Documents\School\UMGC\Capstone Two Preprocessing and Training Data Development\archive\Student_Mental_health.csv')

# %%
Student_Mental_Health
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
dummy = pd.get_dummies(Student_Mental_Health['Choose your gender'])

# %%
dummy.head()
# Out:
#    Female  Male
# 0       1     0
# 1       0     1
# 2       0     1
# 3       1     0
# 4       0     1

# %%
Student_Mental_Health = pd.concat([Student_Mental_Health, dummy], axis=1)

# %%
Student_Mental_Health.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
Student_Mental_Health = Student_Mental_Health.merge(dummy, left_index = True, right_index = True)

# %%
Student_Mental_Health.head()
# Out:
#         Timestamp Choose your gender   Age What is your course?  \
# 0  8/7/2020 12:02             Female  18.0          Engineering
# 1  8/7/2020 12:04               Male  21.0    Islamic education
# 2  8/7/2020 12:05               Male  19.0                  BIT
# 3  8/7/2020 12:06             Female  22.0                 Laws
# 4  8/7/2020 12:13               Male  23.0         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     year 1        3.00 - 3.49             No
# 1                     year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     year 3        3.00 - 3.49            Yes
# 4                     year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# ...

# %%
scaler = preprocessing.StandardScaler()
# Fitting data to the scaler object
scaled_df = scaler.fit_transform(Student_Mental_Health)
scaled_df = pd.DataFrame(scaled_df, columns=names)

# %%
# demonstrate that the train-test split procedure is repeatable
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
X = Student_Mental_Health['Choose your gender']
y = Student_Mental_Health[['Age', 'What is your course?']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
print(X_train)
# Out:
# 48      Male
# 58    Female
# 90    Female
# 98    Female
# 53    Female
#        ...
# 75    Female
# 9       Male
# 72    Female
# 12    Female
# 37    Female
# Name: Choose your gender, Length: 67, dtype: object

# %%
#Does my data set have any categorical data, such as Gender or day of the week?
#Yes

# %%
#Do my features have data values that range from 0 - 100 or 0-1 or both and more?
#No just 0 -24

# %%
Student_Mental_Health['Age'].max()
# Out:
# 24.0
